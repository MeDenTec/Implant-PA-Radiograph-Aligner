# %%
! pip install -r requirements.txt

# %% [markdown]
# ## Implant Aligner
# This Notebook presents the code for the model responsible to align Implants in PA Radiographs with respect to the vertical axis of the image

# %% [markdown]
# ### Import

# %%
import os
import numpy as np
from PIL import Image
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
import random
from skimage.transform import resize
import pandas as pd

# %% [markdown]
# ### Dataset
#
# The dataset contains all the PA radiographs as `X` and the angle of their implant with respect to the vertical axis as `Y`.
#
# #### Data Directory Structure:
#
# - `Dataset/`
#   - `images/`
#   - `labels.csv`
#
# #### Sample from `labels.csv`:
#
# | images       | labels        |
# |--------------|---------------|
# | image1.jpg   | -3.099632121  |
# | image2.jpg   | 7.172982666   |
# | image3.jpg   | 13.27064388   |
# | ...          | ...           |

# %%
print(len(os.listdir("Dataset/images")))
# Out:
# 2883

# %% [markdown]
# ### Utility functions

# %%
from PIL import Image, ExifTags
import os

def normalize_orientation(image):
    try:
        for orientation in ExifTags.TAGS.keys():
            if ExifTags.TAGS[orientation] == 'Orientation':
                break
        exif = image._getexif()
        if exif is not None:
            exif = dict(exif.items())
            orientation_value = exif.get(orientation, None)

            if orientation_value == 3:
                image = image.rotate(180, expand=True)
            elif orientation_value == 6:
                image = image.rotate(270, expand=True)
            elif orientation_value == 8:
                image = image.rotate(90, expand=True)
    except (AttributeError, KeyError, IndexError):
        # cases: image don't have getexif
        pass
    return image

def convert_grayscale_to_rgb(input_path, output_path):
    # Open the image
    image = Image.open(input_path)

    # Normalize the orientation
    image = normalize_orientation(image)

    # Convert to grayscale
    grayscale_image = image.convert("L")

    # Convert to RGB
    rgb_image = Image.merge("RGB", (grayscale_image, grayscale_image, grayscale_image))

    # Save the RGB image
    rgb_image.save(output_path)


def process_images_in_directory(src_directory, dest_directory):
    # Loop through all files in the source directory and its subdirectories
    for root, dirs, files in os.walk(src_directory):
        for file in files:
            # Check if the file is an image (you can adjust the condition based on your file types)
            if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tif','.tiff')):
                src_path = os.path.join(root, file)
                relative_path = os.path.relpath(src_path, src_directory)
                dest_path = os.path.join(dest_directory, relative_path)

                # Ensure the subdirectory structure exists in the destination directory
                os.makedirs(os.path.dirname(dest_path), exist_ok=True)

                # Convert and save the image
                convert_grayscale_to_rgb(src_path, dest_path)

# %% [markdown]
# ### Data Augmentation and preprocessing

# %%
# Define the path to the folder containing TIFF images
image_folder = 'Dataset/images'  # ____________________________ Image mode selection

# Define the path to the CSV file containing angle labels
labels_file = 'Dataset/labels.csv'

def leftRightShift(image):
    image_array = np.array(image)
    # Shifting Augmentation
    shift_amount = random.randint(10, 30)
    shifted_right = np.concatenate((image_array[:, -shift_amount:], image_array[:, :-shift_amount]), axis=1)


    # Left shift
    shift_amount = random.randint(10, 30)
    shifted_left = np.concatenate((image_array[:, shift_amount:], image_array[:, :shift_amount]), axis=1)

    return np.array(shifted_right) / 255.0, np.array(shifted_left) / 255.0


def load_and_preprocess_images(image_folder, labels_file):
    images = []
    angles = []

    # Load the CSV file into a DataFrame
    df = pd.read_csv(labels_file)

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        filename = row['images']
        angle = row['labels']
        image_path = os.path.join(image_folder, filename)

        # Load image and convert to grayscale if necessary
        image = Image.open(image_path)
        image = normalize_orientation(image)
        # print(np.shape(image))
        if image.mode != 'L':
            image = image.convert('L')

        # Resize image to a fixed size (e.g., 128x128)
        image = image.resize((128, 128))   # ___________ img size ____________________

        # Convert image to numpy array and normalize pixel values
        image = np.array(image) / 255.0

        # Append image and angle label to lists
        images.append(image)
        angles.append(float(angle))

    return np.array(images), np.array(angles)

def load_augment_and_preprocess_images(image_folder, labels_file):
    images = []
    angles = []

    # Load the CSV file into a DataFrame
    df = pd.read_csv(labels_file)

    # Iterate over each row in the DataFrame
    for index, row in df.iterrows():
        filename = row['images']
        angle = row['labels']
        image_path = os.path.join(image_folder, filename)

        # Load image and convert to grayscale if necessary
        image = Image.open(image_path)
        image = normalize_orientation(image)
        # If the image is not in grayscale, convert it
        if image.mode != 'L':
            image = image.convert('L')

        # Resize image to a fixed size (e.g., 128x128)
        image = image.resize((128, 128))
        # image = image.resize((256, 256))

        # Convert image to numpy array and normalize pixel values

        # Append image and angle label to lists
        images.append(np.array(image) / 255.0) # original image
        angles.append(float(angle))  # Assuming angles are represented as floating-point numbers
        # aug#2
        rand_angle = random.randint(0, 15) 
        rotated_image_pos = image.rotate(rand_angle)  
        images.append(np.array(rotated_image_pos) / 255.0)
        angles.append(float(angle) + rand_angle)
        # aug#3,4
        # Additional Left Right on rotated
        right, left = leftRightShift(rotated_image_pos)
        images.append(np.array(right) / 255.0)
        images.append(np.array(left) / 255.0)
        angles.append(float(angle) + rand_angle)
        angles.append(float(angle) + rand_angle)
        # aug# 5
        rand_angle = random.randint(-15, 0)
        rotated_image_pos = image.rotate(rand_angle)
        images.append(np.array(rotated_image_pos) / 255.0)
        angles.append(float(angle) + rand_angle)
        # aug# 6,7
        # Additional Left Right on rotated
        right, left = leftRightShift(rotated_image_pos)
        images.append(np.array(right) / 255.0)
        images.append(np.array(left) / 255.0)
        angles.append(float(angle) + rand_angle)
        angles.append(float(angle) + rand_angle)
        # aug#8
        rand_angle = random.randint(15, 30)
        rotated_image_pos = image.rotate(rand_angle)
        images.append(np.array(rotated_image_pos) / 255.0)
        angles.append(float(angle) + rand_angle)
        # aug# 9, 10
        # Additional Left Right on rotated
        right, left = leftRightShift(rotated_image_pos)
        images.append(np.array(right) / 255.0)
        images.append(np.array(left) / 255.0)
        angles.append(float(angle) + rand_angle)
        angles.append(float(angle) + rand_angle)

        # aug# 11
        rand_angle = random.randint(-30, -15)
        rotated_image_pos = image.rotate(rand_angle)
        images.append(np.array(rotated_image_pos) / 255.0)
        angles.append(float(angle) + rand_angle)
        # aug# 12, 13
        # Additional Left Right on rotated
        right, left = leftRightShift(rotated_image_pos)
        images.append(np.array(right) / 255.0)
        images.append(np.array(left) / 255.0)
        angles.append(float(angle) + rand_angle)
        angles.append(float(angle) + rand_angle)

        image_array = np.array(image)
        # Shifting Augmentation
        shift_amount = random.randint(10, 30)
        shifted_right = np.concatenate((image_array[:, -shift_amount:], image_array[:, :-shift_amount]), axis=1)
        # shifted_right = image[:, -shift_amount:]  # Example: Shift by 20 pixels
        images.append(np.array(shifted_right) / 255.0)
        angles.append(float(angle))  # Angle remains unchanged

        # aug# 14, 15
        # Left shift
        shift_amount = random.randint(10, 30)
        shifted_left = np.concatenate((image_array[:, shift_amount:], image_array[:, :shift_amount]), axis=1)
        shifted_left = np.concatenate((image_array[:, shift_amount:], np.zeros((image_array.shape[0], shift_amount))), axis=1)
        # shifted_left = image[:, shift_amount:]  # Example: Shift by 20 pixels
        images.append(np.array(shifted_left) / 255.0)
        angles.append(float(angle))  # Angle remains unchanged

        # Zooming Augmentation
        zoom_factor = random.uniform(0.8, 1.2)  # Random zoom factor between 0.8 and 1.2
        zoomed_image = resize(image_array, (image_array.shape[0], int(image_array.shape[1] * zoom_factor)), anti_aliasing=True)

        # If zoomed in, crop the image
        if zoom_factor > 1:
            zoomed_image = zoomed_image[:, :image_array.shape[1]]
        # If zoomed out, pad the image with black pixels
        elif zoom_factor < 1:
            pad_width = image_array.shape[1] - zoomed_image.shape[1]
            zoomed_image = np.pad(zoomed_image, ((0, 0), (0, pad_width)), mode='constant', constant_values=0)
        # aug# 16
        images.append(np.array(zoomed_image) / 255.0)
        angles.append(float(angle))  # Angle remains unchanged
        # aug# 17
        # Brightness adjustment
        brightness_factor = random.uniform(0.7, 1.3)  # Randomly select brightness factor between 0.8 to 1.2
        image_array_nor = image_array / 255.0
        brightened = np.clip(image_array_nor * brightness_factor, 0, 1)
        images.append(brightened)
        angles.append(float(angle))  # Angle remains unchanged}
# ________________________________________________________________
    return np.array(images), np.array(angles)


augment = True  # Whether to augment or not

if augment is True:
    images, angles = load_augment_and_preprocess_images(image_folder, labels_file)
else:
    images, angles = load_and_preprocess_images(image_folder, labels_file)

# %%
print(np.shape(images))
print(np.shape(angles))
# Out:
# (40307, 128, 128)
# (40307,)

# %% [markdown]
# ### Train, Val and Test split

# %%
# Split the dataset into training, validation, and test sets
train_images, test_images, train_angles, test_angles = train_test_split(images, angles, test_size=0.1, random_state=42)
train_images, val_images, train_angles, val_angles = train_test_split(train_images, train_angles, test_size=0.1, random_state=42)

# %%
print(np.shape(val_images))
# Out:
# (3628, 128, 128)

# %%
np.shape(train_images)
# Out:
# (32648, 128, 128)

# %%
# Define the CNN model
def create_regression_cnn(input_shape):
  model = models.Sequential([
      # Convolutional layers
      layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(128, (3, 3), activation='relu'),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(256, (3, 3), activation='relu'),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(512, (3, 3), activation='relu'),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(512, (3, 3), activation='relu'),
      layers.MaxPooling2D((2, 2)),
      layers.Flatten(),
      # Dense layers for regression
      layers.Dense(1024, activation='relu'),
      layers.Dense(512, activation='linear'),
      layers.Dense(256, activation='linear'),
      layers.Dense(1, activation = 'linear')  # Output layer for regression
      ])
  return model

# Define the CNN model
def create_complex_regression_cnn(input_shape):
  model = models.Sequential([
      # Convolutional layers
      layers.Conv2D(64, (3, 3), activation='relu', input_shape=input_shape, padding = 'same'),
      layers.Conv2D(64, (3, 3), activation='relu'),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(128, (3, 3), activation='relu', padding = 'same'),
      layers.Conv2D(128, (3, 3), activation='relu'),
      layers.MaxPooling2D((2, 2)),
      layers.Conv2D(256, (3, 3), activation='relu'),
      # layers.Conv2D(256, (3, 3), activation='relu', padding = 'same'),
      layers.MaxPooling2D((2, 2)),

      # layers.Conv2D(512, (3, 3), activation='relu', padding = 'same'),
      layers.Conv2D(512, (3, 3), activation='relu'),

      layers.MaxPooling2D((2, 2)),
      # layers.Conv2D(512, (3, 3), activation='relu', padding = 'same'),
      layers.Conv2D(512, (3, 3), activation='relu'),
      layers.MaxPooling2D((2, 2)),
      layers.Flatten(),
      # Dense layers for regression
      layers.Dense(1024, activation='relu'),
      layers.Dense(512, activation='linear'),
      layers.Dense(256, activation='linear'),
      layers.Dense(1)  # Output layer for regression
      ])
  return model

  # Instantiate the model
# input_shape = (256, 256, 1)  # Specify your image dimensions and channels
input_shape = (128, 128, 1)  # Specify your image dimensions and channels

complex_regresion = True  # Whether to create simple regression model or complex

if complex_regresion is True:
  model = create_complex_regression_cnn(input_shape)
else:
  model = create_regression_cnn(input_shape)

model.summary()
# Out:
# d:\262541-Faizan\Implant bone loss project\venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 64)   │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 126, 126, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 63, 63, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 63, 63, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 61, 61, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 30, 30, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 28, 28, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 12, 12, 512)    │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 6, 6, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 2, 2, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 6,848,705 (26.13 MB)
#  Trainable params: 6,848,705 (26.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Calbacks and model training

# %%
#Callback

callback = callbacks.EarlyStopping(
    monitor='val_loss',  # Monitor validation loss
    mode='min',          # Minimize validation loss
    min_delta=0.001,     # Minimum change to qualify as an improvement
    patience=50,         # Number of epochs with no improvement after which training will be stopped
    restore_best_weights=True  # Restore weights from the epoch with the best validation loss
)

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Train the model
metrics = model.fit(train_images,
                    train_angles,
                    epochs=1000,
                    batch_size=128,
                    validation_data=(val_images, val_angles),
                    callbacks=[callback])

# batch_size = 64
# metrics = model.fit(generator,
#                     steps_per_epoch=len(images) // batch_size,
#                     epochs=100,
#                     callbacks=[callback],
#                     validation_data=validation_generator)

# Evaluate the model
loss, mae = model.evaluate(test_images, test_angles)
print("Test Mean Squared Error:", loss)
print("Test Mean Absolute Error:", mae)

# Make predictions
predictions = model.predict(test_images)
# Out:
# Epoch 1/1000
# 256/256 [==============================] - 68s 191ms/step - loss: 358.5827 - mae: 14.8392 - val_loss: 338.6535 - val_mae: 14.3142
# Epoch 2/1000
# 256/256 [==============================] - 46s 180ms/step - loss: 275.5250 - mae: 12.7260 - val_loss: 222.5983 - val_mae: 11.4997
# Epoch 3/1000
# 256/256 [==============================] - 46s 178ms/step - loss:
1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.5141 - mae: 0.5291 - val_loss: 32.7739 - val_mae: 3.2322
# Epoch 248/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4952 - mae: 0.5212 - val_loss: 33.1561 - val_mae: 3.3504
# Epoch 249/1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.5647 - mae: 0.5556 - val_loss: 33.0006 - val_mae: 3.2393
# Epoch 250/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.5535 - mae: 0.5489 - val_loss: 33.2558 - val_mae: 3.2811
# Epoch 251/1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.5151 - mae: 0.5305 - val_loss: 33.5431 - val_mae: 3.2753
# Epoch 252/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4786 - mae: 0.5135 - val_loss: 33.2031 - val_mae: 3.2621
# Epoch 253/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4727 - mae: 0.5093 - val_loss: 33.2010 - val_mae: 3.2642
# Epoch 254/1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.5013 - mae: 0.5230 - val_loss: 33.1156 - val_mae: 3.2738
# Epoch 255/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.6814 - mae: 0.6053 - val_loss: 33.5934 - val_mae: 3.3974
# Epoch 256/1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.8149 - mae: 0.6676 - val_loss: 33.2142 - val_mae: 3.3527
# Epoch 257/1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.6849 - mae: 0.6080 - val_loss: 34.1366 - val_mae: 3.3216
# Epoch 258/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.6067 - mae: 0.5693 - val_loss: 33.7591 - val_mae: 3.2903
# Epoch 259/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.5053 - mae: 0.5213 - val_loss: 32.9892 - val_mae: 3.2390
# Epoch 260/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4154 - mae: 0.4766 - val_loss: 33.2748 - val_mae: 3.2594
# Epoch 261/1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.4087 - mae: 0.4755 - val_loss: 33.3942 - val_mae: 3.2652
# Epoch 262/1000
# 256/256 [==============================] - 45s 176ms/step - loss: 0.4151 - mae: 0.4806 - val_loss: 32.8541 - val_mae: 3.2429
# Epoch 263/1000
# 256/256 [==============================] - 45s 177ms/step - loss: 0.4069 - mae: 0.4742 - val_loss: 33.7693 - val_mae: 3.2688
# 126/126 [==============================] - 5s 28ms/step - loss: 27.7275 - mae: 3.1073
# Test Mean Squared Error: 27.72749900817871
# Test Mean Absolute Error: 3.107335090637207
# 126/126 [==============================] - 2s 18ms/step

# %% [markdown]
# ### Validation

# %%
# Evaluate the model
loss, mae = model.evaluate(test_images, test_angles)
print("Test Mean Squared Error:", loss)
print("Test Mean Absolute Error:", mae)

# Make predictions
predictions = model.predict(test_images)
# Out:
# 126/126 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - loss: 25.2238 - mae: 2.9695
# Test Mean Squared Error: 25.507320404052734
# Test Mean Absolute Error: 3.023515462875366

# %% [markdown]
# ### Prediction on test images

# %%
import pandas as pd

# Evaluate the model
loss, mae = model.evaluate(test_images, test_angles)
print("Test Mean Squared Error:", loss)
print("Test Mean Absolute Error:", mae)

# Make predictions
predictions = model.predict(test_images)

# Create a DataFrame to visualize the differences
results_df = pd.DataFrame({
    'Test Angles': test_angles,
    'Predicted Angles': predictions.flatten()
})

# Print the DataFrame
print(results_df)
# Out:
# 8/8 [==============================] - 0s 11ms/step - loss: 63.0958 - mae: 3.6835
# Test Mean Squared Error: 63.09576416015625
# Test Mean Absolute Error: 3.683526039123535
# 8/8 [==============================] - 0s 10ms/step
#      Test Angles  Predicted Angles
# 0      -7.145106        -12.049554
# 1      -1.005086         -3.567605
# 2      15.561510         19.468838
# 3      -0.505538         -0.915460
# 4      13.279365         13.359903
# ..           ...               ...
# 233   -11.967102        -20.426786
# 234   -15.655782        -15.408672
# 235     1.901236         -0.040355
# 236    -0.309704          1.083019
# 237     7.731785          5.420019
#
# [238 rows x 2 columns]

# %%
results_df
# Out:
#      Test Angles  Predicted Angles
# 0      -7.145106         -7.335417
# 1      -1.005086         -1.342367
# 2      15.561510         12.261539
# 3      -0.505538         -0.980649
# 4      13.279365         13.287255
# ..           ...               ...
# 233   -11.967102        -16.406130
# 234   -15.655782        -15.185789
# 235     1.901236          2.879450
# 236    -0.309704         -3.128719
# 237     7.731785         10.317285
#
# [238 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# results_df['Test Angles'].plot(kind='hist', bins=20, title='Test Angles')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# results_df['Predicted Angles'].plot(kind='hist', bins=20, title='Predicted Angles')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# results_df.plot(kind='scatter', x='Test Angles', y='Predicted Angles', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# results_df['Test Angles'].plot(kind='line', figsize=(8, 4), title='Test Angles')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# results_df['Predicted Angles'].plot(kind='line', figsize=(8, 4), title='Predicted Angles')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# ## Rotation Function for directory

# %% [markdown]
# In order to load the pretrained model, run the following command

# %%
model = models.load_model('/content/drive/MyDrive/DMFT_datasets/Implant_bone_loss/implant_aligner_2371Withaug_WOrgb263epoch_cpu.keras')

# %%
# Prediction function

def process_image(image_path):
  image_arr = []
  # Load image and convert to grayscale if necessary
  image = Image.open(image_path)
  # If the image is not in grayscale, convert it
  if image.mode != 'L':
      image = image.convert('L')

  image = normalize_orientation(image)

  # rgb_image = Image.merge("RGB", (grayscale_image, grayscale_image, grayscale_image)) # __________converting to rgb
  # Resize image to a fixed size (e.g., 128x128)
  image = image.resize((128, 128))

  # Convert image to numpy array and normalize pixel values
  image = np.array(image) / 255.0

  # Append image and angle label to lists
  image_arr.append(image)
  return np.array(image_arr)

# %%
# rotation function

def rotate_image(image_path, angle, output_path):
  image_arr = []
  # Load image and convert to grayscale if necessary
  image = Image.open(image_path)

  rot_img = image.rotate(angle, Image.NEAREST, expand = 1)
  rot_img.save(os.path.join(output_path, os.path.basename(image_path)))

# %%
output_path = 'path/to/Directory_containing_PA_images'

input_path = 'path/to/aligned_output_images'
os.makedirs(output_path, exist_ok= True)

# for x in range(151,169,1):
for img in os.listdir(input_path):
  path = os.path.join(input_path,img)
  arr = process_image(path)
  # print(np.shape(arr))
  pred_arr = arr.reshape((1, 128, 128, 1))
  predictions = model.predict(pred_arr)
  rotate_image(path,predictions[0][0],output_path)
  print(os.path.basename(path))
  print(predictions[0])
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (684).jpg
# [5.815711]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (724).jpg
# [-6.554394]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (598).jpg
# [-11.357008]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (99).jpg
# [2.225787]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (170).jpg
# [5.770026]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (389).jpg
# [-1.0280272]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (53).tif
# [-1.5198296]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (230).tif
# [-3.6597884]
# 1/1 [==============================] - 0s 21ms/step
# MBL Implant (152).tif
# [3.6348686]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (189).tif
# [1.4641862]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (16).png
# [-11.068403]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (841).jpg
# [6.506121]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (524).jpg
# [26.049562]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (151).jpg
# [-4.0696487]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (586).jpg
# [-9.481863]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (314).tif
# [-17.125698]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (283).tif
# [3.1377468]
# 1/1 [==============================] - 0s 27ms/step
# gen_implant (456).png
# [8.607637]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (356).png
# [-29.025202]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (483).jpg
# [10.390465]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (322).png
# [8.640276]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (54).jpg
# [8.932815]
# 1/1 [==============================] - 0s 16ms/step
# Implant internet (584).jpg
# [-10.000105]
# 1/1 [==============================] - 0s 16ms/step
# Implant internet (678).jpg
# [-9.146854]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (360).tif
# [-8.196226]
# 1/1 [==============================] - 0s 22ms/step
# gen_implant (169).png
# [-14.273596]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (243).png
# [-22.427113]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (682).jpg
# [-2.2170155]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (826).jpg
# [0.550835]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (312).tif
# [-5.4904366]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (415).jpg
# [-8.138969]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (769).jpg
# [-6.0336294]
# 1/1 [==============================] - 0s 16ms/step
# Implant internet (527).jpg
# [-18.816895]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (263).jpg
# [-27.862389]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (106).png
# [3.9174998]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (358).tif
# [13.350931]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (454).jpg
# [10.355682]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (386).tif
# [22.35345]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (11).jpg
# [-3.689031]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (315).jpg
# [1.4263868]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (296).png
# [-14.578712]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (103).tif
# [6.9066577]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (471).jpg
# [-22.037437]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (290).jpg
# [-1.9178126]
# 1/1 [==============================] - 0s 21ms/step
# MBL Implant (92).tif
# [0.05111438]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (729).jpg
# [-4.076876]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (779).jpg
# [-0.60145456]
# 1/1 [==============================] - 0s 25ms/step
# gen_implant (161).png
# [-15.294557]
# 1/1 [==============================] - 0s 36ms/step
# Implant internet (795).jpg
# [2.3681886]
# 1/1 [==============================] - 0s 24ms/step
# gen_implant (566).png
# [12.75355]
# 1/1 [==============================] - 0s 27ms/step
# gen_implant (61).png
# [-4.995281]
# 1/1 [==============================] - 0s 26ms/step
# gen_implant (655).png
# [0.5987599]
# 1/1 [==============================] - 0s 26ms/step
# MBL Implant (343).tif
# [-4.9016438]
# 1/1 [==============================] - 0s 24ms/step
# Implant internet (27).jpg
# [3.8231776]
# 1/1 [==============================] - 0s 24ms/step
# gen_implant (64).png
# [-0.12583534]
# 1/1 [==============================] - 0s 29ms/step
# gen_implant (195).png
# [-10.331003]
# 1/1 [==============================] - 0s 31ms/step
# gen_implant (110).png
# [-0.43180954]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (336).jpg
# [-0.8020645]
# 1/1 [==============================] - 0s 30ms/step
# MBL Implant (214).tif
# [0.6073648]
# 1/1 [==============================] - 0s 35ms/step
# Implant internet (765).jpg
# [0.7517594]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (431).jpg
# [11.107319]
# 1/1 [==============================] - 0s 41ms/step
# Implant internet (655).jpg
# [9.797748]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (328).jpg
# [-7.80888]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (323).jpg
# [3.0207672]
# 1/1 [==============================] - 0s 28ms/step

# 1/1 [==============================] - 0s 19ms/step
# Implant internet (78).jpg
# [-0.3527195]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (604).png
# [-6.678952]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (787).jpg
# [1.3676007]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (410).jpg
# [-15.587751]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (696).jpg
# [3.0702658]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (715).jpg
# [-7.5701237]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (416).jpg
# [-0.60883445]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (45).png
# [1.883769]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (628).jpg
# [12.553501]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (77).jpg
# [-14.061035]
# 1/1 [==============================] - 0s 19ms/step
# MBL Implant (38).tif
# [-3.7763882]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (668).jpg
# [9.170709]
# 1/1 [==============================] - 0s 16ms/step
# Implant internet (572).jpg
# [-7.0337267]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (589).jpg
# [-22.387072]
# 1/1 [==============================] - 0s 22ms/step
# gen_implant (533).png
# [6.7195864]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (268).png
# [8.348288]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (300).jpg
# [-8.739788]
# 1/1 [==============================] - 0s 16ms/step
# Implant internet (461).jpg
# [0.20349655]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (248).tif
# [-6.5555387]
# 1/1 [==============================] - 0s 16ms/step
# Implant internet (854).jpg
# [6.98604]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (14).png
# [-4.055957]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (502).png
# [-7.0121374]
# 1/1 [==============================] - 0s 26ms/step
# Implant internet (560).jpg
# [-9.47118]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (482).png
# [-6.939096]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (840).jpg
# [-19.001198]
# 1/1 [==============================] - 0s 16ms/step
# gen_implant (38).png
# [5.471734]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (753).jpg
# [-1.3258438]
# 1/1 [==============================] - 0s 16ms/step
# MBL Implant (320).tif
# [-5.5942006]
# 1/1 [==============================] - 0s 16ms/step
# Implant internet (467).jpg
# [-29.855362]
# 1/1 [==============================] - 0s 21ms/step
# MBL Implant (31).tif
# [8.163115]
# 1/1 [==============================] - 0s 31ms/step
# Implant internet (329).jpg
# [6.1238317]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (281).png
# [-5.4162474]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (760).jpg
# [7.2162514]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (249).tif
# [-1.9695897]
# 1/1 [==============================] - 0s 19ms/step
# MBL Implant (104).tif
# [6.8295097]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (601).jpg
# [-2.639745]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (142).tif
# [-4.321566]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (375).jpg
# [7.153383]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (293).png
# [-2.5032542]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (516).jpg
# [-23.103683]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (846).jpg
# [-12.089525]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (33).jpg
# [-5.831427]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (494).jpg
# [1.1060895]
# 1/1 [==============================] - 0s 23ms/step
# gen_implant (7).png
# [14.217769]
# 1/1 [==============================] - 0s 27ms/step
# MBL Implant (304).tif
# [4.627345]
# 1/1 [==============================] - 0s 26ms/step
# gen_implant (318).png
# [18.88538]
# 1/1 [==============================] - 0s 24ms/step
# Implant internet (64).jpg
# [4.607754]
# 1/1 [==============================] - 0s 39ms/step
# gen_implant (374).png
# [8.471696]
# 1/1 [==============================] - 0s 24ms/step
# Implant internet (442).jpg
# [4.827789]
# 1/1 [==============================] - 0s 28ms/step
# gen_implant (626).png
# [-5.825713]
# 1/1 [==============================] - 0s 33ms/step
# gen_implant (33).png
# [-10.537319]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (713).jpg
# [-8.599921]
# 1/1 [==============================] - 0s 29ms/step
# Implant internet (739).jpg

# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (353).tif
# [-12.534967]
# 1/1 [==============================] - 0s 28ms/step
# MBL Implant (319).tif
# [2.8598797]
# 1/1 [==============================] - 0s 29ms/step
# gen_implant (564).png
# [-6.387059]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (774).jpg
# [28.912542]
# 1/1 [==============================] - 0s 34ms/step
# MBL Implant (155).tif
# [-0.3620228]
# 1/1 [==============================] - 0s 28ms/step
# MBL Implant (374).tif
# [-4.834506]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (470).jpg
# [-5.547158]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (820).jpg
# [-15.179286]
# 1/1 [==============================] - 0s 26ms/step
# MBL Implant (182).tif
# [-11.163679]
# 1/1 [==============================] - 0s 25ms/step
# gen_implant (130).png
# [0.8227137]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (330).jpg
# [-11.01506]
# 1/1 [==============================] - 0s 26ms/step
# Implant internet (649).jpg
# [11.969284]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (278).jpg
# [-6.960474]
# 1/1 [==============================] - 0s 30ms/step
# gen_implant (627).png
# [1.9993224]
# 1/1 [==============================] - 0s 30ms/step
# MBL Implant (105).tif
# [15.409711]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (493).jpg
# [11.108452]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (749).jpg
# [0.25662738]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (334).jpg
# [-0.20154336]
# 1/1 [==============================] - 0s 28ms/step
# gen_implant (239).png
# [-7.245268]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (577).jpg
# [19.700668]
# 1/1 [==============================] - 0s 34ms/step
# gen_implant (150).png
# [-18.766827]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (476).jpg
# [5.9204454]
# 1/1 [==============================] - 0s 35ms/step
# gen_implant (552).png
# [-12.036858]
# 1/1 [==============================] - 0s 34ms/step
# gen_implant (295).png
# [-19.598343]
# 1/1 [==============================] - 0s 30ms/step
# gen_implant (53).png
# [-0.5448359]
# 1/1 [==============================] - 0s 35ms/step
# Implant internet (7).jpg
# [1.0602946]
# 1/1 [==============================] - 0s 28ms/step
# MBL Implant (8).tif
# [-2.446356]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (804).jpg
# [1.4477944]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (750).jpg
# [-10.2676525]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (451).png
# [8.640276]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (594).jpg
# [5.316645]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (550).jpg
# [6.81885]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (21).jpg
# [-8.796564]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (786).jpg
# [13.581509]
# 1/1 [==============================] - 0s 24ms/step
# gen_implant (251).png
# [11.386858]
# 1/1 [==============================] - 0s 28ms/step
# gen_implant (503).png
# [9.355299]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (167).jpg
# [14.706821]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (345).png
# [-6.165913]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (3).png
# [-1.7196851]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (447).png
# [8.628517]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (414).png
# [-2.5032542]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (436).png
# [-4.993127]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (802).jpg
# [0.663487]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet

# 1/1 [==============================] - 0s 21ms/step
# Implant internet (399).jpg
# [-4.889889]
# 1/1 [==============================] - 0s 23ms/step
# Implant internet (801).jpg
# [1.8954085]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (432).jpg
# [-15.779069]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (328).png
# [5.8021607]
# 1/1 [==============================] - 0s 48ms/step
# Implant internet (599).jpg
# [-13.368353]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (656).jpg
# [12.019953]
# 1/1 [==============================] - 0s 29ms/step
# Implant internet (822).jpg
# [-10.791728]
# 1/1 [==============================] - 0s 30ms/step
# gen_implant (664).png
# [-1.1356463]
# 1/1 [==============================] - 0s 31ms/step
# Implant internet (803).jpg
# [29.555798]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (448).jpg
# [6.766616]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (437).jpg
# [-7.5999365]
# 1/1 [==============================] - 0s 34ms/step
# Implant internet (248).jpg
# [11.965623]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (349).jpg
# [0.5016874]
# 1/1 [==============================] - 0s 28ms/step
# MBL Implant (340).tif
# [-6.4001255]
# 1/1 [==============================] - 0s 26ms/step
# Implant internet (314).jpg
# [-9.296214]
# 1/1 [==============================] - 0s 28ms/step
# MBL Implant (297).tif
# [-6.714386]
# 1/1 [==============================] - 0s 39ms/step
# Implant internet (746).jpg
# [21.655676]
# 1/1 [==============================] - 0s 25ms/step
# MBL Implant (68).tif
# [5.1737905]
# 1/1 [==============================] - 0s 34ms/step
# gen_implant (203).png
# [-5.4807825]
# 1/1 [==============================] - 0s 36ms/step
# Implant internet (863).jpg
# [-1.3523233]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (499).jpg
# [-1.3644814]
# 1/1 [==============================] - 0s 29ms/step
# Implant internet (512).jpg
# [14.0742235]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (554).jpg
# [-13.578287]
# 1/1 [==============================] - 0s 29ms/step
# MBL Implant (256).tif
# [6.064828]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (700).jpg
# [13.449505]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (203).jpg
# [-4.9823065]
# 1/1 [==============================] - 0s 39ms/step
# Implant internet (443).jpg
# [4.784692]
# 1/1 [==============================] - 0s 34ms/step
# Implant internet (475).jpg
# [-7.92694]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (771).jpg
# [-14.668512]
# 1/1 [==============================] - 0s 37ms/step
# Implant internet (321).jpg
# [1.3943634]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (539).jpg
# [14.068591]
# 1/1 [==============================] - 0s 36ms/step
# gen_implant (59).png
# [-13.794666]
# 1/1 [==============================] - 0s 31ms/step
# Implant internet (736).jpg
# [17.986774]
# 1/1 [==============================] - 0s 32ms/step
# gen_implant (588).png
# [-18.507883]
# 1/1 [==============================] - 0s 31ms/step
# gen_implant (82).png
# [-6.0511765]
# 1/1 [==============================] - 0s 35ms/step
# Implant internet (776).jpg
# [18.913338]
# 1/1 [==============================] - 0s 49ms/step
# Implant internet (559).jpg
# [1.6609676]
# 1/1 [==============================] - 0s 33ms/step
# gen_implant (101).png

# 1/1 [==============================] - 0s 20ms/step
# gen_implant (331).png
# [0.30942535]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (576).jpg
# [6.9128423]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (521).png
# [-4.024094]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (92).jpg
# [-14.422386]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (293).jpg
# [-11.537832]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (706).jpg
# [-1.5360272]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (18).jpg
# [2.8118956]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (851).jpg
# [9.334729]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (287).jpg
# [-4.8055396]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (292).jpg
# [-1.2525208]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (799).jpg
# [6.9683285]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (612).jpg
# [2.2954895]
# 1/1 [==============================] - 0s 24ms/step
# Implant internet (34).jpg
# [5.9763365]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (675).png
# [19.43739]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (561).png
# [0.47095147]
# 1/1 [==============================] - 0s 19ms/step
# MBL Implant (379).tif
# [2.7079966]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (364).png
# [15.105374]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (67).png
# [-4.400318]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (603).jpg
# [33.52518]
# 1/1 [==============================] - 0s 29ms/step
# gen_implant (514).png
# [2.4271986]
# 1/1 [==============================] - 0s 25ms/step
# gen_implant (29).png
# [-1.1983707]
# 1/1 [==============================] - 0s 26ms/step
# Implant internet (57).jpg
# [0.78729934]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (546).jpg
# [-16.909472]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (310).jpg
# [7.485887]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (10).jpg
# [3.5729718]
# 1/1 [==============================] - 0s 40ms/step
# MBL Implant (250).tif
# [-24.907131]
# 1/1 [==============================] - 0s 31ms/step
# Implant internet (788).jpg
# [11.339434]
# 1/1 [==============================] - 0s 26ms/step
# Implant internet (458).jpg
# [-22.534946]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (478).jpg
# [-27.883015]
# 1/1 [==============================] - 0s 28ms/step
# MBL Implant (159).tif
# [-1.0070443]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (791).jpg
# [-15.431328]
# 1/1 [==============================] - 0s 36ms/step
# Implant internet (718).jpg
# [1.6071172]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (636).jpg
# [3.3181484]
# 1/1 [==============================] - 0s 37ms/step
# Implant internet (359).jpg
# [7.7178698]
# 1/1 [==============================] - 0s 35ms/step
# Implant internet (735).jpg
# [6.608463]
# 1/1 [==============================] - 0s 26ms/step
# gen_implant (585).png
# [0.7325617]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (712).jpg
# [12.627697]
# 1/1 [==============================] - 0s 30ms/step
# gen_implant (457).png
# [-4.882179]
# 1/1 [==============================] - 0s 31ms/step
# gen_implant (359).png
# [-1.6567776]
# 1/1 [==============================] - 0s 29ms/step
# MBL Implant (316).tif
# [2.8573506]
# 1/1 [==============================] - 0s 29ms/step
# gen_implant (119).png
# [-5.767642]
# 1/1 [==============================] - 0s 39ms/step
# Implant internet (261).jpg
# [-0.93703014]
# 1/1 [==============================] - 0s 31ms/step
# MBL Implant (378).tif
# [-2.7446332]
# 1/1 [==============================] - 0s 31ms/step
# gen_implant (167).png
# [1.1750047]
# 1/1 [==============================] - 0s 31ms/step
# Implant internet (631).jpg
# [7.772336]
# 1/1 [==============================] - 0s 36ms/step
# Implant internet (642).jpg
# [-1.071178]
# 1/1 [==============================] - 0s 31ms/step
# Implant internet (727).jpg
# [12.023842]
# 1/1 [==============================] - 0s 34ms/step
# Implant internet (624).jpg
# [16.107403]
# 1/1 [==============================] - 0s 34ms/step
# gen_implant (452).png
# [-0.91703534]
# 1/1 [==============================] - 0s 34ms/step
# Implant internet (36).jpg
# [-2.4722571]
# ...
# gen_implant (213).png
# [6.0100117]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (130).tif
# [-0.12687941]
# 1/1 [==============================] - 0s 21ms/step
# MBL Implant (132).tif
# [4.0278826]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (393).jpg
# [-12.990939]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (653).jpg
# [-3.1348598]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (731).jpg
# [19.695581]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (356).jpg
# [-12.072297]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (362).tif
# [-8.303067]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (860).jpg
# [-0.4888499]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (767).jpg
# [-3.4578884]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (93).jpg
# [-10.190745]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (48).jpg
# [2.3855903]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (603).png
# [-1.6567776]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (95).jpg
# [-7.0217752]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (184).jpg
# [-19.478529]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (414).jpg
# [-18.068838]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (104).jpg
# [-10.581313]
# 1/1 [==============================] - 0s 19ms/step
# gen_implant (6).png
# [-9.718822]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (96).jpg
# [5.500663]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (63).jpg
# [-0.9013307]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (347).jpg
# [1.6982534]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (386).png
# [-8.452494]
# 1/1 [==============================] - 0s 21ms/step
# MBL Implant (317).tif
# [-6.4577417]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (338).jpg
# [1.5212834]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (89).jpg
# [-2.2296047]
# 1/1 [==============================] - 0s 20ms/step
# MBL Implant (180).tif
# [-5.2166495]
# 1/1 [==============================] - 0s 22ms/step
# gen_implant (290).png
# [15.578051]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (348).jpg
# [-6.9528394]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (669).jpg
# [15.385601]
# 1/1 [==============================] - 0s 28ms/step
# gen_implant (11).png
# [-5.4162474]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (756).jpg
# [-11.431978]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (583).jpg
# [-20.799713]
# 1/1 [==============================] - 0s 30ms/step
# gen_implant (680).png
# [-1.8396887]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (807).jpg
# [22.342747]
# 1/1 [==============================] - 0s 26ms/step
# gen_implant (256).png
# [-4.0533285]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (611).jpg
# [12.308451]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (327).jpg
# [-6.453264]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (542).jpg
# [-6.354969]
# 1/1 [==============================] - 0s 28ms/step
# gen_implant (206).png
# [1.2425683]
# 1/1 [==============================] - 0s 34ms/step
# gen_implant (551).png
# [-24.07368]
# 1/1 [==============================] - 0s 26ms/step
# MBL Implant (150).tif
# [-0.10935789]
# 1/1 [==============================] - 0s 24ms/step
# Implant internet (704).jpg
# [1.4641619]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (864).jpg
# [-2.768326]
# 1/1 [==============================] - 0s 31ms/step
# gen_implant (490).png
# [5.2327623]
# 1/1 [==============================] - 0s 34ms/step
# gen_implant (501).png
# [-3.9798076]
# 1/1 [==============================] - 0s 32ms/step
# MBL Implant (75).tif
# [0.9557277]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (686).jpg
# [-2.2869458]
# 1/1 [==============================] - 0s 28ms/step
# MBL Implant (226).tif
# [-7.251359]
# 1/1 [==============================] - 0s 26ms/step
# Implant internet (850).jpg
# [-9.28479]
# 1/1 [==============================] - 0s 34ms/step
# MBL Implant (339).tif
# [-8.023999]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (515).jpg
# [-0.9475149]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (532).jpg
# [5.610128]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (31).jpg
# [-9.022621]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (412).jpg
# [10.342263]
# 1/1 [==============================] - 0s 33ms/step
# gen_implant (642).png
# [-3.1806781]
# 1/1 [==============================] - 0s 46ms/step
# Implant internet (453).jpg
# [-5.3405066]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (271).jpg
# [7.163953]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (210).jpg
# [-5.3314376]
# 1/1 [==============================] - 0s 45ms/step
# MBL Implant (354).tif
# [-14.506933]
# 1/1 [==============================] - 0s 31ms/step
# MBL Implant (190).tif
# [0.12147639]
# 1/1 [==============================] - 0s 36ms/step
# Implant internet (798).jpg
# [-2.0671997]
# 1/1 [==============================] - 0s 40ms/step
# gen_implant (21).png
# [-2.5032542]
# 1/1 [==============================] - 0s 31ms/step
# MBL Implant (5).tif
# [-5.2936726]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (331).jpg
# [4.747936]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (132).jpg
# [-0.8973878]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (55).jpg
# [-10.730402]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (365).jpg
# [-0.63665414]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (819).jpg
# [11.046772]
# 1/1 [==============================] - 0s 21ms/step
# MBL Implant (137).tif
# [4.032533]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (70).jpg
# [11.086155]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (327).png
# [-0.5448359]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (433).png
# [5.7453227]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (592).png
# [-20.566021]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (265).tif
# [6.0450125]
# 1/1 [==============================] - 0s 29ms/step
# Implant internet (301).jpg
# [5.368972]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (455).jpg
# [8.2830105]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (541).jpg
# [6.7045507]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (463).png
# [-10.331003]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (661).jpg
# [-11.016062]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (149).tif
# [10.466457]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (681).jpg
# [-2.3424513]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (98).jpg
# [-3.9470236]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (479).jpg
# [-39.705326]
# 1/1 [==============================] - 0s 22ms/step
# MBL Implant (279).tif
# [-7.149188]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (420).png
# [-8.941823]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (752).jpg
# [-11.315677]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (859).jpg
# [-2.978871]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (24).tif
# [-8.3926525]
# 1/1 [==============================] - 0s 21ms/step
# gen_implant (565).png
# [4.3180094]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (781).jpg
# [6.003576]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (449).jpg
# [-6.406278]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (133).png
# [8.896177]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (812).jpg
# [-10.003563]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (417).jpg
# [1.790082]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (818).jpg
# [-3.1004398]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (645).jpg
# [-5.3621054]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (140).tif
# [-5.9176297]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (396).jpg
# [-7.5494018]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (294).png
# [-4.586565]
# 1/1 [==============================] - 0s 23ms/step
# MBL Implant (85).tif
# [0.40019444]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (602).png
# [-17.064938]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (543).jpg
# [26.53561]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (383).jpg
# [-5.4273467]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (681).png
# [12.393227]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (6).tif
# [3.1038456]
# 1/1 [==============================] - 0s 22ms/step
# gen_implant (469).png
# [6.199075]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (285).jpg
# [-10.269641]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (59).jpg
# [2.15334]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (253).jpg
# [0.8763561]
# 1/1 [==============================] - 0s 19ms/step
# MBL Implant (176).tif
# [-2.107939]
# 1/1 [==============================] - 0s 29ms/step
# Implant internet (640).jpg
# [-20.14523]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (13).jpg
# [-17.077854]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (618).jpg
# [20.52286]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (371).tif
# [-15.1855755]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (291).png
# [-8.512968]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (600).jpg
# [-4.0572066]
# 1/1 [==============================] - 0s 20ms/step
# Implant internet (3).jpg
# [-11.135105]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (202).png
# [15.681974]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (510).jpg
# [-12.157226]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (348).png
# [26.727736]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (661).png
# [3.7293546]
# 1/1 [==============================] - 0s 19ms/step
# MBL Implant (183).tif
# [-4.278592]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (875).jpg
# [3.1274283]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (21).tif
# [2.887921]
# 1/1 [==============================] - 0s 20ms/step
# gen_implant (679).png
# [1.1192604]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (39).png
# [-4.993127]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (761).jpg
# [-9.936848]
# 1/1 [==============================] - 0s 22ms/step
# Implant internet (766).jpg
# [-10.593004]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (168).png
# [13.027801]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (250).jpg
# [-5.404497]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (218).jpg
# [-10.631658]
# 1/1 [==============================] - 0s 21ms/step
# Implant internet (434).jpg
# [-6.2846365]
# 1/1 [==============================] - 0s 23ms/step
# Implant internet (529).jpg
# [-3.9947526]
# 1/1 [==============================] - 0s 18ms/step
# MBL Implant (174).tif
# [-8.21728]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (457).jpg
# [0.19683787]
# 1/1 [==============================] - 0s 18ms/step
# gen_implant (570).png
# [5.5865574]
# 1/1 [==============================] - 0s 23ms/step
# MBL Implant (324).tif
# [-6.544442]
# 1/1 [==============================] - 0s 22ms/step
# gen_implant (435).png
# [5.471734]
# 1/1 [==============================] - 0s 19ms/step
# Implant internet (615).jpg
# [16.057259]
# 1/1 [==============================] - 0s 17ms/step
# gen_implant (267).png
# [0.15399247]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (523).jpg
# [-62.247738]
# 1/1 [==============================] - 0s 28ms/step
# gen_implant (427).png
# [1.1750047]
# 1/1 [==============================] - 0s 36ms/step
# Implant internet (525).jpg
# [18.630083]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (610).jpg
# [-4.4162197]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (719).jpg
# [-9.894317]
# 1/1 [==============================] - 0s 24ms/step
# MBL Implant (309).tif
# [8.628761]
# 1/1 [==============================] - 0s 24ms/step
# gen_implant (388).png
# [14.217769]
# 1/1 [==============================] - 0s 43ms/step
# Implant internet (644).jpg
# [-8.845954]
# 1/1 [==============================] - 0s 25ms/step
# MBL Implant (376).tif
# [8.159136]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (507).jpg
# [11.884996]
# 1/1 [==============================] - 0s 25ms/step
# gen_implant (309).png
# [1.1750047]
# 1/1 [==============================] - 0s 39ms/step
# gen_implant (166).png
# [-8.962065]
# 1/1 [==============================] - 0s 25ms/step
# gen_implant (645).png
# [3.9659183]
# 1/1 [==============================] - 0s 32ms/step
# gen_implant (193).png
# [6.2740006]
# 1/1 [==============================] - 0s 32ms/step
# MBL Implant (19).tif
# [-8.451454]
# 1/1 [==============================] - 0s 25ms/step
# Implant internet (319).jpg
# [-1.2673357]
# 1/1 [==============================] - 0s 27ms/step
# MBL Implant (337).tif
# [-12.458501]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (407).jpg
# [-11.278305]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (481).jpg
# [36.52804]
# 1/1 [==============================] - 0s 38ms/step
# Implant internet (214).jpg
# [-8.924102]
# 1/1 [==============================] - 0s 26ms/step
# gen_implant (429).png
# [13.027801]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (784).jpg
# [-6.829505]
# 1/1 [==============================] - 0s 27ms/step
# Implant internet (237).jpg
# [-15.125265]
# 1/1 [==============================] - 0s 26ms/step
# MBL Implant (43).tif
# [-14.666599]
# 1/1 [==============================] - 0s 30ms/step
# Implant internet (368).jpg
# [-10.146919]
# 1/1 [==============================] - 0s 33ms/step
# Implant internet (302).jpg
# [-3.33417]
# 1/1 [==============================] - 0s 45ms/step
# Implant internet (625).jpg
# [18.85306]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (444).jpg
# [-0.30495295]
# 1/1 [==============================] - 0s 28ms/step
# Implant internet (629).jpg
# [16.466642]
# 1/1 [==============================] - 0s 31ms/step
# Implant internet (533).jpg
# [3.8196793]
# 1/1 [==============================] - 0s 45ms/step
# gen_implant (555).png
# [4.2523365]
# 1/1 [==============================] - 0s 30ms/step
# gen_implant (192).png
# [-10.84477]
# 1/1 [==============================] - 0s 32ms/step
# Implant internet (570).jpg
# [10.619763]
# 1/1 [==============================] - 0s 28ms/step
# gen_implant (378).png
# [6.277564]
# 1/1 [==============================] - 0s 31ms/step
# gen_implant (84).png
# [-3.1619618]
# 1/1 [==============================] - 0s 26ms/step
# MBL Implant (294).tif
# [-3.5290444]
# 1/1 [==============================] - 0s 30ms/step
# gen_implant (103).png
# [9.355299]
# 1/1 [==============================] - 0s 18ms/step
# Implant internet (29).jpg
# [15.768654]
# 1/1 [==============================] - 0s 17ms/step
# Implant internet (614).jpg
# [-17.449907]
# 1/1 [==============================] - 0s 17ms/step
# MBL Implant (151).tif
# [-6.7259774]
